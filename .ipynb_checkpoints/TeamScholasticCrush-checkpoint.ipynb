# %%
import pandas as pd
import csv
import numpy as np
import matplotlib as plt
import requests
from pprint import pprint
import scipy.stats as stats

# %%
csvpath = "Resources/Public_School_Data.csv"
raw_data = pd.read_csv(csvpath)
charter_schools_data = pd.read_csv("Resources/1617_CS_ACHIEVEMENT.csv")

# %%
public_df = raw_data[["Building Name", "District Name", "County", "City, State, Zip Code", "Performance Index Score 2015-16"]]
charter_schools_df = charter_schools_data.loc[:, ['Building Name', 'District Name', 'County', 'City and Zip Code', 'Performance Index Percent 2016-17']]

# %%
charter_schools_df[["City", "State", "Zip Code"]] = charter_schools_df["City and Zip Code"].str.split(",",expand=True).rename(columns=lambda x: f"string_{x+1}")
charter_schools_df.head()
# Out:
#                     Building Name                   District Name      County  \
# 0     Pathway School of Discovery     Pathway School of Discovery  Montgomery
# 1  Alliance Academy of Cincinnati  Alliance Academy of Cincinnati    Hamilton
# 2  Wildwood Environmental Academy  Wildwood Environmental Academy       Lucas
# 3   Ohio Connections Academy, Inc   Ohio Connections Academy, Inc    Cuyahoga
# 4          Quaker Digital Academy           New Philadelphia City  Tuscarawas
#
#                   City and Zip Code Performance Index Percent 2016-17  \
# 0            Dayton, OH, 45404-2123                              66.2
# 1        Cincinnati, OH, 45207-1644                              53.8
# 2            Maumee, OH, 43537-1374                              61.7
# 3         Cleveland, OH, 44115-2229                              64.7
# 4  New Philadelphia, OH, 44663-2150                              54.5
#
#                City State     Zip Code
# 0            Dayton    OH   45404-2123
# 1        Cincinnati    OH   45207-1644
# 2            Maumee    OH   43537-1374
# 3         Cleveland    OH   44115-2229
# 4  New Philadelphia    OH   44663-2150

# %%
charter_schools_df[["City", "State", "Zip Code"]] = charter_schools_df["City and Zip Code"].str.split(",",expand=True).rename(columns=lambda x: f"string_{x+1}")
charter_schools_df[["Zip Code", "Code+4"]] = charter_schools_df["Zip Code"].str.split("-",expand=True).rename(columns=lambda x: f"string_{x+1}")
charter_schools_df = charter_schools_df.loc[charter_schools_df["Performance Index Percent 2016-17"] != "NC"]
charter_schools_df.head()
# Out:
#                     Building Name                   District Name      County  \
# 0     Pathway School of Discovery     Pathway School of Discovery  Montgomery
# 1  Alliance Academy of Cincinnati  Alliance Academy of Cincinnati    Hamilton
# 2  Wildwood Environmental Academy  Wildwood Environmental Academy       Lucas
# 3   Ohio Connections Academy, Inc   Ohio Connections Academy, Inc    Cuyahoga
# 4          Quaker Digital Academy           New Philadelphia City  Tuscarawas
#
#                   City and Zip Code Performance Index Percent 2016-17  \
# 0            Dayton, OH, 45404-2123                              66.2
# 1        Cincinnati, OH, 45207-1644                              53.8
# 2            Maumee, OH, 43537-1374                              61.7
# 3         Cleveland, OH, 44115-2229                              64.7
# 4  New Philadelphia, OH, 44663-2150                              54.5
#
#                City State Zip Code Code+4
# 0            Dayton    OH    45404   2123
# 1        Cincinnati    OH    45207   1644
# 2            Maumee    OH    43537   1374
# 3         Cleveland    OH    44115   2229
# 4  New Philadelphia    OH    44663   2150

# %%
public_df[["City","State", "Zip Code"]] = public_df["City, State, Zip Code"].str.split(",",expand=True)
public_df.head()
# Out:
# C:\Users\jnovic\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
#                Building Name         District Name  County  \
# 0      Ada Elementary School  Ada Exempted Village  Hardin
# 1            Ada High School  Ada Exempted Village  Hardin
# 2     Sandusky Middle School         Sandusky City    Erie
# 3       Meigs Primary School           Meigs Local   Meigs
# 4  Meigs Intermediate School           Meigs Local   Meigs
#
#         City, State, Zip Code Performance Index Score 2015-16        City  \
# 0         Ada, OH, 45810-1013                          96.125         Ada
# 1         Ada, OH, 45810-1013                          91.667         Ada
# 2    Sandusky, OH, 44870-2616                          62.772    Sandusky
# 3  Middleport, OH, 45760-9717                              NC  Middleport
# 4  Middleport, OH, 45760-9717                          70.394  Middleport
#
#   State     Zip Code
# 0    OH   45810-1013
# 1    OH   45810-1013
# 2    OH   44870-2616
# 3    OH   45760-9717
# 4    OH   45760-9717

# %%
public_df.to_csv("Resources/Public_ZipCode.csv", index=False, header=True)

# %%
public_df = public_df.loc[public_df["Performance Index Score 2015-16"] != "NC"]

# %%
csvpath2 = "Resources/Ethnicity.csv"
raw_data_race = pd.read_csv(csvpath2)
ethnic_df = pd.read_csv(csvpath2)
# Out:
# C:\Users\jnovic\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
### Replace the >95


race_df = raw_data_race[["Building Name", "Student Group","% of Total Enrollment"]]
race_df = race_df.replace(to_replace = "NC", value = 0)
race_df = race_df.replace(to_replace = ">95", value = 95.1)
# Out:
#            Building Name                      Student Group  \
# 0  Ada Elementary School  American Indian or Alaskan Native
# 1  Ada Elementary School          Asian or Pacific Islander
# 2  Ada Elementary School                              Black
# 3  Ada Elementary School                           Hispanic
# 4  Ada Elementary School                        Multiracial
# 5  Ada Elementary School                              White
# 6        Ada High School  American Indian or Alaskan Native
# 7        Ada High School          Asian or Pacific Islander
# 8        Ada High School                              Black
# 9        Ada High School                           Hispanic
#
#   % of Total Enrollment
# 0                     0
# 1                     0
# 2                   3.4
# 3                     0
# 4                     0
# 5                  92.5
# 6                     0
# 7                     0
# 8                     0
# 9                     0

# %%
df_white = race_df.loc[race_df["Student Group"] == "White", :]
df_latinx = race_df.loc[race_df["Student Group"] == "Hispanic", :]
df_black = race_df.loc[race_df["Student Group"] == "Black", :]

# %%
public_race_white = df_white.merge(public_df, on="Building Name")
public_race_latinx = df_latinx.merge(public_df, on="Building Name")
public_race_black = df_black.merge(public_df, on="Building Name")

charterwhite_df = pd.merge(charter_schools_df, df_white, on="Building Name") 
charterblack_df = pd.merge(charter_schools_df, df_black, on="Building Name") 
charterhispanic_df = pd.merge(charter_schools_df, df_latinx, on="Building Name")

# %%
csvpath3 = "Resources/Economic.csv"
raw_data_econ = pd.read_csv(csvpath3)
raw_data_econ.head()
# Out:
#    Building IRN           Building Name  District IRN         District Name  \
# 0            59   Ada Elementary School         45187  Ada Exempted Village
# 1            59   Ada Elementary School         45187  Ada Exempted Village
# 2            67         Ada High School         45187  Ada Exempted Village
# 3            67         Ada High School         45187  Ada Exempted Village
# 4            83  Sandusky Middle School         44743         Sandusky City
#
#    County    Region Open/Closed Status as of 9/12/2017        School Type  \
# 0  Hardin  Region 6                               Open  Elementary School
# 1  Hardin  Region 6                               Open  Elementary School
# 2  Hardin  Region 6                               Open        High School
# 3  Hardin  Region 6                               Open        High School
# 4    Erie  Region 2                               Open      Middle School
#
#       Student Group Read 3rd Grade 2016-2017 % Proficient or above    ...     \
# 0     Disadvantaged                                           77.4    ...
# 1  NonDisadvantaged                                           92.3    ...
# 2     Disadvantaged                                             NC    ...
# 3  NonDisadvantaged                                             NC    ...
# 4     Disadvantaged                                             NC    ...
#
#   Geometry End of Course 2016-2017 % Proficient or Above  \
# 0                                                 NC
# 1                                                 NC
# 2                                               56.0
# 3                                               62.9
# 4                                                 NC
#
#   Integrated Math I End of Course 2016-2017 % Proficient or Above  \
# 0                                                 NC
# 1                                                 NC
# 2                                                 NC
# 3                                                 NC
# 4                                                 NC
#
#   Integrated Math II End of Course 2016-2017 % Proficient or Above  \
# 0                                                 NC
# 1                                                 NC
# 2                                                 NC
# 3                                                 NC
# 4                                                 NC
#
#   Biology End of Course 2016-2017 % Proficient or Above  \
# 0                                                 NC
# 1                                                 NC
# 2                                               75.0
# 3                                               89.6
# 4                                                 NC
#
#   Attendance rate 2016-2017  \
# 0                     >95.0
# 1                     >95.0
# 2                      92.6
# 3                      94.7
# 4                      94.0
#
#   4-Year Longitudinal Graduation Rate - Class of 2016  \
# 0                                                 NC
# 1                                                 NC
# 2                                               78.9
# 3                                              >95.0
# 4                                                 NC
#
#   5-Year Longitudinal Graduation Rate - Class of 2015 Enrollment  \
# 0                                                 NC         201
# 1                                                 NC         264
# 2                                               92.3         155
# 3                                               94.0         235
# 4                                                 NC         443
#
#   % of Total Enrollment Watermark
# 0                  43.2       NaN
# 1                  56.8       NaN
# 2                  39.7       NaN
# 3                  60.3       NaN
# 4                 >95.0       NaN
#
# [5 rows x 41 columns]

# %%
###Replace the >9

econ_df = raw_data_econ[["Building Name", "Student Group","% of Total Enrollment"]]
econ_df = econ_df.replace(to_replace = "NC", value = 0)
econ_df = econ_df.replace(to_replace = >95, value = 95.1)
# Out:
#   File "<ipython-input-50-17ea28f201f5>", line 3
#     econ_df = econ_df.replace(to_replace = >95, value = 95.1)
#                                            ^
# SyntaxError: invalid syntax

# %%
df_poor = econ_df.loc[econ_df["Student Group"] == "Disadvantaged", :]
df_notpoor = econ_df.loc[econ_df["Student Group"] == "NonDisadvantaged", :]

# %%
public_poor_df = df_poor.merge(public_df, on="Building Name")
public_notpoor_df = df_notpoor.merge(public_df, on="Building Name")

charter_disadvantaged = pd.merge(charter_schools_df, df_poor, on="Building Name")
charter_nondisadvantaged = pd.merge(charter_schools_df, df_notpoor, on="Building Name")

# %%
public_black_cuya = public_race_black.loc[public_race_black["County"] == "Cuyahoga", :]
public_white_cuya =  public_race_white.loc[public_race_white["County"] == "Cuyahoga", :]
public_latinx_cuya =  public_race_latinx.loc[public_race_latinx["County"] == "Cuyahoga", :]
public_poor_cuya = public_poor_df.loc[public_poor_df["County"] == "Cuyahoga", :]
public_notpoor_cuya = public_notpoor_df.loc[public_notpoor_df["County"] == "Cuyahoga", :]

charter_nondisadv_cuyahoga = charter_nondisadvantaged.loc[charter_nondisadvantaged["County"] == "Cuyahoga"]
charter_disadv_cuyahoga = charter_disadvantaged.loc[charter_disadvantaged["County"] == "Cuyahoga"]
charterwhite_cuyahoga = charterwhite_df.loc[charterwhite_df["County"] == "Cuyahoga"]
charterblack_cuyahoga = charterblack_df.loc[charterblack_df["County"] == "Cuyahoga"]
charterhispanic_cuyahoga = charterhispanic_df.loc[charterhispanic_df["County"] == "Cuyahoga"]

# %%
public_black_frank = public_race_black.loc[public_race_black["County"] == "Franklin", :]
public_white_frank =  public_race_white.loc[public_race_white["County"] == "Franklin", :]
public_latinx_frank =  public_race_latinx.loc[public_race_latinx["County"] == "Franklin", :]
public_poor_frank = public_poor_df.loc[public_poor_df["County"] == "Franklin", :]
public_notpoor_frank = public_notpoor_df.loc[public_notpoor_df["County"] == "Franklin", :]

charter_nondisadv_franklin = charter_nondisadvantaged.loc[charter_nondisadvantaged["County"] == "Franklin"]
charter_disadv_franklin = charter_disadvantaged.loc[charter_disadvantaged["County"] == "Franklin"]
charterwhite_franklin = charterwhite_df.loc[charterwhite_df["County"] == "Franklin"]
charterblack_franklin = charterblack_df.loc[charterblack_df["County"] == "Franklin"]
charterhispanic_franklin = charterhispanic_df.loc[charterhispanic_df["County"] == "Franklin"]

# %%
public_black_ham = public_race_black.loc[public_race_black["County"] == "Hamilton", :]
public_white_ham =  public_race_white.loc[public_race_white["County"] == "Hamilton", :]
public_latinx_ham =  public_race_latinx.loc[public_race_latinx["County"] == "Hamilton", :]
public_poor_ham = public_poor_df.loc[public_poor_df["County"] == "Hamilton", :]
public_notpoor_ham = public_notpoor_df.loc[public_notpoor_df["County"] == "Hamilton", :]

charter_nondisadv_hamilton = charter_nondisadvantaged.loc[charter_nondisadvantaged["County"] == "Hamilton"]
charter_disadv_hamilton = charter_disadvantaged.loc[charter_disadvantaged["County"] == "Hamilton"]
charterwhite_hamilton = charterwhite_df.loc[charterhispanic_df["County"] == "Hamilton"]
charterblack_hamilton = charterblack_df.loc[charterblack_df["County"] == "Hamilton"]
charterhispanic_hamilton = charterhispanic_df.loc[charterblack_df["County"] == "Hamilton"]

# %%
public_black_ham
# Out:
#                                          Building Name Student Group  \
# 15                      Alliance Academy of Cincinnati         Black
# 41        Summit Academy Community School - Cincinnati         Black
# 135                                      Orion Academy         Black
# 139                      King Academy Community School         Black
# 143   Summit Academy Transition High School-Cincinnati         Black
# 157                            Amity Elementary School         Black
# 161                               Anderson High School         Black
# 177                 Horizon Science Academy-Cincinnati         Black
# 214        Mt. Healthy Preparatory and Fitness Academy         Black
# 346                                Blue Ash Elementary         Black
# 355                Bond Hill Academy Elementary School         Black
# 377                           Bridgetown Middle School         Black
# 428                     C O Harrison Elementary School         Black
# 476                 Dater Montessori Elementary School         Black
# 513                Central Community Elementary School         Black
# 534             Charles W Springmyer Elementary School         Black
# 536                            Chase Elementary School         Black
# 547                          Cheviot Elementary School         Black
# 574               North College Hill Elementary School         Black
# 581                         Colerain Elementary School         Black
# 583                         Colerain Elementary School         Black
# 584                               Colerain High School         Black
# 585                             Colerain Middle School         Black
# 586                   College Hill Fundamental Academy         Black
# 619                         Covedale Elementary School         Black
# 661                           Crosby Elementary School         Black
# 684                       Gilbert A. Dater High School         Black
# 693                        Deer Park Jr/Sr High School         Black
# 711                                Delhi Middle School         Black
# 736               Frederick Douglass Elementary School         Black
# ...                                                ...           ...
# 3535                             Norwood Middle School         Black
# 3541                            Ayer Elementary School         Black
# 3562                       Sycamore Junior High School         Black
# 3563                    Winton Woods Elementary School         Black
# 3597                                Turpin High School         Black
# 3603          School For Creat & Perf Arts High School         Black
# 3609                Woodford Paideia Elementary School         Black
# 3635      Academy Of World Languages Elementary School         Black
# 3912  Hamilton          Cincinnati, OH, 45237-3802
# 3913  Hamilton          Cincinnati, OH, 45224-3101
# 3917  Hamilton          Cincinnati, OH, 45225-1001
#
#      Performance Index Score 2015-16                City State     Zip Code
# 15                            56.718          Cincinnati    OH   45207-1644
# 41                            51.304          Cincinnati    OH   45237-3805
# 135                           56.381          Cincinnati    OH   45214-1427
# 139                           80.538          Cincinnati    OH   45202-6990
# 143                           41.270          Cincinnati    OH   45224-3029
# 157                           89.972          Cincinnati    OH   45236-2618
# 161                           93.282          Cincinnati    OH   45255-4307
# 177                           48.668          Cincinnati    OH   45237-5005
# 214                           57.910          Cincinnati    OH   45231-3107
# 346                           98.978          Cincinnati    OH   45236-1007
# 355                           49.258          Cincinnati    OH   45237-5621
# 377                           95.283          Cincinnati    OH   45211-4300
# 428                          100.292          Cincinnati    OH   45233-4610
# 476                           94.984          Cincinnati    OH   45238-2425
# 513                           85.350             Reading    OH   45215-3322
# 534                          103.277          Cincinnati    OH   45248-1505
# 536                           68.245          Cincinnati    OH   45223-2218
# 547                           70.352          Cincinnati    OH   45211-4644
# 574                           68.209  North College Hill    OH   45239-4459
# 581                           79.569          Cincinnati    OH   45251-1808
# 583                           79.569          Cincinnati    OH   45251-1808
# 584                           67.142          Cincinnati    OH   45251-5907
# 585                           75.383          Cincinnati    OH   45251-1806
# 586                           74.771          Cincinnati    OH   45224-2824
# 619                           91.676          Cincinnati    OH   45238-3712
# 661                          104.147            Harrison    OH   45030-9207
# 684                           56.009          Cincinnati    OH   45238-3720
# 693                           78.000          Cincinnati    OH   45236-2445
# 711                           90.310          Cincinnati    OH   45238-4810
# 736                           48.410          Cincinnati    OH   45206-1476
# ...                              ...                 ...   ...          ...
# 3535                          78.450             Norwood    OH   45212-2616
# 3541                          99.451          Cincinnati    OH   45255-4700
# 3562                          97.823          Cincinnati    OH   45242-7015
# 3563                          71.030          Cincinnati    OH   45240-2121
# 3597                          97.759          Cincinnati    OH   45244-4009
# 3603                          81.700          Cincinnati    OH   45202-7211
# 3609                          62.650          Cincinnati    OH   45213-2270
# 3635                          54.458          Cincinnati    OH   45207-1943
# 3653                          76.213          Cincinnati    OH   45208-2406
# 3662                         106.780            Loveland    OH   45140-8229
# 3666                          96.689            Harrison    OH   45030-8969
# 3691                         100.375            Loveland    OH   45140-2703
# 3709                         100.649          Cincinnati    OH   45227-3600
# 3762                          91.245          Cincinnati    OH   45213-1624
# 3767                          73.356          Cincinnati    OH   45229-2609
# 3768                          60.491          Cincinnati    OH   45214-2605
# 3776                          52.828          Cincinnati    OH   45204-1214
# 3789                          93.139          Cincinnati    OH   45233-4555
# 3794                          98.824          Cincinnati    OH   45255-2544
# 3823                          93.924            Loveland    OH   45140-9308
# 3845                          61.030          Cincinnati    OH   45203-1462
# 3866                          76.972          Cincinnati    OH   45231-1311
# 3880                          44.738          Cincinnati    OH   45238-3720
# 3881                          63.826          Cincinnati    OH   45237-4007
# 3883                          52.205          Cincinnati    OH   45226-2180
# 3896                          49.343          Cincinnati    OH   45208-1216
# 3910                          56.245          Cincinnati    OH   45204-1604
# 3912                          42.895          Cincinnati    OH   45237-3802
# 3913                          47.458          Cincinnati    OH   45224-3101
# 3917                          57.561          Cincinnati    OH   45225-1001
#
# [198 rows x 10 columns]
